# %%
import pandas as pd

# %%
data_original=pd.read_csv("~/Downloads/loan.csv")

# %%
data=data_original.copy()

# %%
data.head(5)
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599     5000.0       5000.0           4975.0   36 months
# 1  1077430    1314167     2500.0       2500.0           2500.0   60 months
# 2  1077175    1313524     2400.0       2400.0           2400.0   36 months
# 3  1076863    1277178    10000.0      10000.0          10000.0   36 months
# 4  1075358    1311748     3000.0       3000.0           3000.0   60 months
#
#    int_rate  installment grade sub_grade     ...      total_bal_il il_util  \
# 0     10.65       162.87     B        B2     ...               NaN     NaN
# 1     15.27        59.83     C        C4     ...               NaN     NaN
# 2     15.96        84.33     C        C5     ...               NaN     NaN
# 3     13.49       339.31     C        C1     ...               NaN     NaN
# 4     12.69        67.79     B        B5     ...               NaN     NaN
#
# ...

# %%
data["term"]=data['term'].str.slice(0,3,1)
data.head(5)
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv term  int_rate  \
# 0  1077501    1296599     5000.0       5000.0           4975.0   36     10.65
# 1  1077430    1314167     2500.0       2500.0           2500.0   60     15.27
# 2  1077175    1313524     2400.0       2400.0           2400.0   36     15.96
# 3  1076863    1277178    10000.0      10000.0          10000.0   36     13.49
# 4  1075358    1311748     3000.0       3000.0           3000.0   60     12.69
#
#    installment grade sub_grade     ...      total_bal_il il_util open_rv_12m  \
# 0       162.87     B        B2     ...               NaN     NaN         NaN
# 1        59.83     C        C4     ...               NaN     NaN         NaN
# 2        84.33     C        C5     ...               NaN     NaN         NaN
# 3       339.31     C        C1     ...               NaN     NaN         NaN
# 4        67.79     B        B5     ...               NaN     NaN         NaN
#
# ...

# %%
data['term']=data['term'].astype('int16')

# %%
data['term'].dtype
data['grade2']=data['grade'].astype('category')

# %%
data.head(5)
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  term  \
# 0  1077501    1296599     5000.0       5000.0           4975.0    36
# 1  1077430    1314167     2500.0       2500.0           2500.0    60
# 2  1077175    1313524     2400.0       2400.0           2400.0    36
# 3  1076863    1277178    10000.0      10000.0          10000.0    36
# 4  1075358    1311748     3000.0       3000.0           3000.0    60
#
#    int_rate  installment grade sub_grade  ...   il_util open_rv_12m  \
# 0     10.65       162.87     B        B2  ...       NaN         NaN
# 1     15.27        59.83     C        C4  ...       NaN         NaN
# 2     15.96        84.33     C        C5  ...       NaN         NaN
# 3     13.49       339.31     C        C1  ...       NaN         NaN
# 4     12.69        67.79     B        B5  ...       NaN         NaN
#
#   open_rv_24m  max_bal_bc all_util total_rev_hi_lim inq_fi total_cu_tl  \
# ...

# %%
print(data['grade2'].dtype,
      data['grade'].dtype)
# Out:
# category object

# %%
#data['grade'].get_dummies(['A','B','C','D'])
data = data.append(pd.get_dummies(data['grade']),sort=True)

# %%
data.head(5)
# Out:
#     A   B   C   D   E   F   G  acc_now_delinq addr_state  all_util   ...     \
# 0 NaN NaN NaN NaN NaN NaN NaN             0.0         AZ       NaN   ...
# 1 NaN NaN NaN NaN NaN NaN NaN             0.0         GA       NaN   ...
# 2 NaN NaN NaN NaN NaN NaN NaN             0.0         IL       NaN   ...
# 3 NaN NaN NaN NaN NaN NaN NaN             0.0         CA       NaN   ...
# 4 NaN NaN NaN NaN NaN NaN NaN             0.0         OR       NaN   ...
#
#     total_pymnt  total_pymnt_inv total_rec_int  total_rec_late_fee  \
# 0   5861.071414          5831.78        861.07                0.00
# 1   1008.710000          1008.71        435.17                0.00
# 2   3003.653644          3003.65        603.65                0.00
# 3  12226.302212         12226.30       2209.33               16.97
# 4   3242.170000          3242.17       1009.07                0.00
#
#    total_rec_prncp  total_rev_hi_lim  \
# 0          5000.00               NaN
# 1           456.46               NaN
# ...

# %%
data.shape
# Out:
# (7099032, 82)
